# %%
# importing libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
# for visualisation
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Importing the datasets
college_df = pd.read_csv("final_college_df.csv", index_col=0)

# %%
college_train = college_df[college_df['year'] <= 2018]
college_train
# Out:
#               pos  year     player_name   Ortg   usg   eFG  TS_per  ORB_per  \
# 137        Wing F  2014    aaron gordon  105.5  23.2  51.6   50.27     10.4
# 158    Scoring PG  2016   aaron holiday   94.5  20.4  46.2   50.03      2.0
# 159    Scoring PG  2017   aaron holiday  113.1  23.2  57.1   60.96      1.5
# 160    Scoring PG  2018   aaron holiday  112.9  27.2  55.7   60.87      1.6
# 296        Wing G  2016     abdel nader  103.5  20.7  55.5   58.35      2.9
# ...           ...   ...             ...    ...   ...   ...     ...      ...
# 44372      Wing F  2014    willie green  110.8  26.3  52.7   56.25      7.8
# 44581           C  2018  xavier tillman  121.8  15.7  65.0   65.82     14.7
# 44670  Scoring PG  2016    yogi ferrell  124.9  24.7  55.0   59.99      3.5
# 44808           C  2017    zach collins  120.6  24.8  67.6   70.32     12.2
# 44913      Wing G  2014     zach lavine  107.3  19.0  52.4   54.48      2.4
#
# ...

# %%
college_c = pd.read_csv("c_college_df.csv", index_col=0)
college_c_g = pd.read_csv("c_g_college_df.csv", index_col=0)
college_pf_c = pd.read_csv("pf_c_college_df.csv", index_col=0)
college_p_pg = pd.read_csv("p_pg_college_df.csv", index_col=0)
college_s_pg = pd.read_csv("s_pg_college_df.csv", index_col=0)
college_s_4 = pd.read_csv("s_4_college_df.csv", index_col=0)
college_w_g = pd.read_csv("w_g_college_df.csv", index_col=0)
college_w_f = pd.read_csv("w_f_college_df.csv", index_col=0)

# %%
college_c_train = college_c[college_c['year'] <= 2018]
college_c_g_train = college_c_g[college_c_g['year'] <= 2018]
college_pf_c_train = college_pf_c[college_pf_c['year'] <= 2018]
college_p_pg_train = college_p_pg[college_p_pg['year'] <= 2018]
college_s_pg_train = college_s_pg[college_s_pg['year'] <= 2018]
college_s_4_train = college_s_4[college_s_4['year'] <= 2018]
college_w_g_train = college_w_g[college_w_g['year'] <= 2018]
college_w_f_train = college_w_f[college_w_f['year'] <= 2018]

# %%
college_c_train.columns
# Out:
# Index(['pos', 'year', 'player_name', 'Ortg', 'eFG', 'TS_per', 'ORB_per',
#        'DRB_per', 'twoP_per', 'blk_per', 'stl_per', 'porpag', 'adjoe', 'mp',
#        'ogbpm', 'dgbpm', 'pts', 'season', 'ast/tov',
#        'rimmade/(rimmade+rimmiss)', 'drtg', 'dporpag', 'stops', 'gbpm',
#        'score'],
#       dtype='object')

# %%
college_pred = college_df[college_df['year'] > 2018]

college_c_pred = college_c[college_c['year'] > 2018]
college_c_g_pred = college_c_g[college_c_g['year'] > 2018]
college_pf_c_pred = college_pf_c[college_pf_c['year'] > 2018]
college_p_pg_pred = college_p_pg[college_p_pg['year'] > 2018]
college_s_pg_pred = college_s_pg[college_s_pg['year'] > 2018]
college_s_4_pred = college_s_4[college_s_4['year'] > 2018]
college_w_g_pred = college_w_g[college_w_g['year'] > 2018]
college_w_f_pred = college_w_f[college_w_f['year'] > 2018]

# %%
#Centre training
college_c_train = college_c_train.dropna()
x_train = college_c_train.iloc[:,3:-2].values
y_train = college_c_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)

# %%
x_pred = college_c_pred.iloc[:,3:-2].values
y_pred = college_c_pred.iloc[:,-1].values
y_pred = y_pred.reshape(-1, 1)

# %%
# create an empty linear regression model like below and give it a good variable name
c_model = LinearRegression()

# to create the model, we use fit(x,y)
c_model.fit(x_train,y_train)

predictions = c_model.predict(x_pred)

# %%
college_c_pred['test_score'] = predictions
college_c_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/3919065566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_c_pred['test_score'] = predictions
#       pos  year     player_name   Ortg   eFG  TS_per  ORB_per  DRB_per  \
# 4420    C  2019  brandon clarke  134.3  69.3   69.89     13.9     19.7
# 9565    C  2019  daniel gafford  112.3  65.9   65.11     11.2     22.7
# 17342   C  2020  isaiah stewart  115.7  57.7   62.92     10.6     19.4
# 20250   C  2019    jaxson hayes  133.8  72.8   73.90      8.8     16.2
# 34424   C  2020  onyeka okongwu  119.1  61.9   64.60     12.4     18.4
#
#        twoP_per  blk_per  ...      pts  season   ast/tov  \
# 4420      0.705     10.8  ...  16.9459       2  1.210581
# ...

# %%
predictions = c_model.predict(x_train)
college_c_train['test_score'] = predictions
college_c_train
# Out:
#       pos  year          player_name   Ortg   eFG  TS_per  ORB_per  DRB_per  \
# 1225    C  2012             alex len   98.6  55.3   56.54      8.8     20.0
# 1226    C  2013             alex len  112.7  53.5   56.97     13.2     19.3
# 1803    C  2012       andre drummond  100.7  53.8   50.93     14.2     15.5
# 2055    C  2010     andrew nicholson  112.5  56.1   59.67      9.1     17.9
# 2295    C  2012        anthony davis  133.8  62.8   65.41     11.6     23.9
# ...    ..   ...                  ...    ...   ...     ...      ...      ...
# 44056   C  2015       wesley johnson   92.2  41.7   41.83      7.6     10.9
# 44357   C  2014  willie cauley stein  118.9  59.6   57.95     12.6     16.3
# 44358   C  2015  willie cauley stein  115.8  57.2   58.79     11.1     17.3
# 44359   C  2013  willie cauley stein  103.5  62.1   57.66     12.0     17.2
# 44808   C  2017         zach collins  120.6  67.6   70.32     12.2     23.2
#
# ...

# %%
college_c_pred.to_csv('c_scores.csv')

# %%
college_c_train['diff'] = college_c_train['test_score'] - college_c_train['score']
college_c_train.to_csv('analyse_c_scores.csv')

# %%
#Combo G training
college_c_g_train = college_c_g_train.dropna()
x_train = college_c_g_train.iloc[:,3:-2].values
y_train = college_c_g_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)

# %%
x_pred = college_c_g_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
c_g_model = LinearRegression()

# to create the model, we use fit(x,y)
c_g_model.fit(x_train,y_train)

predictions = c_g_model.predict(x_pred)

# %%
college_c_g_pred['test_score'] = predictions
college_c_g_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/2310847517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_c_g_pred['test_score'] = predictions
#            pos  year        player_name  twoPM    porpag     adjoe     adrtg  \
# 4692   Combo G  2020       brandon rush     22 -0.130129   83.1206  114.5860
# 4694   Combo G  2022       brandon rush     84  1.671720  103.0020  118.0530
# 8230   Combo G  2019         coby white    106  3.697480  124.8860   92.0853
# 8322   Combo G  2020       cole anthony     82  3.446230  113.9900   95.2872
# 23102  Combo G  2019       jordan poole     86  3.222610  115.5780   88.1995
# 28677  Combo G  2019      luguentz dort    120  2.458700  110.2400   97.3090
# ...

# %%
predictions = c_g_model.predict(x_train)
college_c_g_train['test_score'] = predictions
college_c_g_train.head(15)
# Out:
#            pos  year        player_name  twoPM   porpag     adjoe     adrtg  \
# 3275   Combo G  2012      austin rivers    116  3.41399  115.5480   97.2284
# 3365   Combo G  2010      avery bradley    117  2.32709  108.7070   92.5408
# 4558   Combo G  2011     brandon knight    130  4.52621  122.7470   94.5951
# 5536   Combo G  2014        bryn forbes     65  3.33733  116.5420  106.2660
# 5538   Combo G  2015        bryn forbes     40  2.34711  113.9300   96.8531
# 5539   Combo G  2016        bryn forbes     53  4.49225  134.4390   99.0640
# 6180   Combo G  2016       caris levert     48  5.23009  136.4290  100.0760
# 8018   Combo G  2012        cj mccollum    192  5.14360  130.0400   91.5530
# 8020   Combo G  2013        cj mccollum     63  5.50317  136.4040   96.5057
# 8833   Combo G  2011        cory joseph     84  2.66713  110.1580   89.5381
# 9291   Combo G  2012     damian lillard    129  6.32296  137.9660  103.5350
# ...

# %%
college_c_g_pred.to_csv('c_g_scores.csv')

# %%
college_c_g_train['diff'] = college_c_g_train['test_score'] - college_c_g_train['score']
college_c_g_train.to_csv('analyse_c_g_scores.csv')

# %%
#PF/C training
college_pf_c_train = college_pf_c_train.dropna()
x_train = college_pf_c_train.iloc[:,3:-2].values
y_train = college_pf_c_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_pf_c_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
pf_c_model = LinearRegression()

# to create the model, we use fit(x,y)
pf_c_model.fit(x_train,y_train)

predictions = pf_c_model.predict(x_pred)

# %%
college_pf_c_pred['test_score'] = predictions
college_pf_c_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/218434202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_pf_c_pred['test_score'] = predictions
#         pos  year       player_name  TS_per  DRB_per  blk_per   ftr     dgbpm  \
# 7328   PF/C  2020     chris johnson   25.38     17.8      1.8  85.7  0.554281
# 10790  PF/C  2019         dean wade   57.33     16.8      2.2  28.6  3.489300
# 18675  PF/C  2019   jalen mcdaniels   52.66     22.7      1.9  28.3  1.588110
# 22679  PF/C  2021       jordan bell   52.92     27.9      4.2  13.2  2.393780
# 22680  PF/C  2022       jordan bell   40.53     26.1      3.5  14.3  0.508150
# 33329  PF/C  2019          naz reid   54.37     19.4      2.8  35.1  0.060076
# ...

# %%
predictions = pf_c_model.predict(x_train)
college_pf_c_train['test_score'] = predictions
college_pf_c_train.head(20)
# Out:
#         pos  year          player_name  TS_per  DRB_per  blk_per   ftr  \
# 946    PF/C  2010      al farouq aminu   52.40     20.5      4.5  53.2
# 1868   PF/C  2013       andre roberson   52.40     27.1      4.4  35.6
# 1869   PF/C  2012       andre roberson   56.83     29.2      6.8  56.8
# 1870   PF/C  2011       andre roberson   60.21     25.1      5.0  44.9
# 2054   PF/C  2012     andrew nicholson   63.77     22.8      7.3  42.9
# 2056   PF/C  2011     andrew nicholson   61.41     19.0      4.5  55.9
# 4124   PF/C  2014         bobby portis   56.18     16.8      5.9  37.3
# 4125   PF/C  2015         bobby portis   58.23     20.2      4.8  33.5
# 4421   PF/C  2017       brandon clarke   58.72     22.2      8.2  36.9
# 7103   PF/C  2016        chris boucher   62.43     20.6     11.9  51.7
# 7104   PF/C  2017        chris boucher   58.98     19.6     11.7  32.0
# 7827   PF/C  2014       christian wood   50.51     18.6      6.8  29.9
# ...

# %%
jjj = college_pf_c_train[college_pf_c_train['year']==2018]
jjj
# Out:
#         pos  year        player_name  TS_per  DRB_per  blk_per   ftr    dgbpm  \
# 16191  PF/C  2018     grant williams   54.44     14.6      5.1  54.8  2.49258
# 19684  PF/C  2018   jaren jackson jr   64.71     19.7     14.2  57.3  6.66517
# 25600  PF/C  2018   keita bates diop   57.73     24.5      5.9  27.4  2.83435
# 30428  PF/C  2018  marvin bagley iii   64.35     21.4      2.6  47.5  1.34425
# 43981  PF/C  2018  wendell carter jr   62.81     23.1      7.6  52.7  4.45957
#
#           blk  season  dporpag      gbpm      score  test_score
# 16191  1.2571       3  3.76987   5.10712  43.411514   41.586444
# 19684  3.0000       4  3.55732  10.56720  65.643213   60.099887
# 25600  1.6471       2  4.62406  10.29700  37.981521   47.419905
# 30428  0.8788       4  4.41523   9.64470  36.119403   49.673410
# 43981  2.0541       4  3.90976  10.36600  43.098792   58.423908

# %%
college_pf_c_train['diff'] = college_pf_c_train['test_score'] - college_pf_c_train['score']
college_pf_c_train.to_csv('analyse_pf_c_scores.csv')

# %%
#Pure PG training
college_p_pg_train = college_p_pg_train.dropna()
x_train = college_p_pg_train.iloc[:,3:-2].values
y_train = college_p_pg_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_p_pg_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
p_pg_model = LinearRegression()

# to create the model, we use fit(x,y)
p_pg_model.fit(x_train,y_train)

predictions = p_pg_model.predict(x_pred)

# %%
college_p_pg_pred['test_score'] = predictions
college_p_pg_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/4137554598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_p_pg_pred['test_score'] = predictions
#            pos  year player_name   usg  AST_per  twoP_per  porpag     ast  \
# 17609  Pure PG  2019   ja morant  36.0     51.4     0.545  6.4241  9.9394
#
#           stl     blk      pts  season   ast/tov     score  test_score
# 17609  1.7576  0.8182  24.4848       3  1.929418  79.01919   52.101772

# %%
predictions = p_pg_model.predict(x_train)
college_p_pg_train['test_score'] = predictions
college_p_pg_train
# Out:
#            pos  year              player_name   usg  AST_per  twoP_per  \
# 1124   Pure PG  2014              alex caruso  21.1     36.7     0.520
# 1125   Pure PG  2016              alex caruso  17.5     31.1     0.572
# 1127   Pure PG  2015              alex caruso  21.0     34.8     0.506
# 1716   Pure PG  2010             amir johnson  15.6     30.2     0.407
# 6070   Pure PG  2015            cameron payne  31.3     39.8     0.507
# 6071   Pure PG  2014            cameron payne  29.6     34.1     0.453
# 7331   Pure PG  2010            chris johnson  15.5     29.3     0.312
# 7332   Pure PG  2011            chris johnson  19.5     31.3     0.484
# 11335  Pure PG  2016         denzel valentine  28.9     45.8     0.481
# 12200  Pure PG  2018          devonte' graham  25.2     31.4     0.392
# 15362  Pure PG  2016            fred vanvleet  24.7     39.6     0.396
# 15363  Pure PG  2015            fred vanvleet  25.1     35.3     0.461
# ...

# %%
college_p_pg_train['diff'] = college_p_pg_train['test_score'] - college_p_pg_train['score']
college_p_pg_train.to_csv('analyse_p_pg_scores.csv')

# %%
#Scoring PG training
college_s_pg_train = college_s_pg_train.dropna()
x_train = college_s_pg_train.iloc[:,3:-2].values
y_train = college_s_pg_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_s_pg_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
s_pg_model = LinearRegression()

# to create the model, we use fit(x,y)
s_pg_model.fit(x_train,y_train)

predictions = s_pg_model.predict(x_pred)

# %%
college_s_pg_pred['test_score'] = predictions
college_s_pg_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/3085736183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_s_pg_pred['test_score'] = predictions
#               pos  year               player_name   Ortg   eFG  TS_per  \
# 8278   Scoring PG  2019               cody martin  119.0  56.4   59.58
# 29083  Scoring PG  2020             malachi flynn  121.5  53.2   58.25
# 33782  Scoring PG  2019  nickeil alexander walker  109.8  54.6   58.59
# 34997  Scoring PG  2019          payton pritchard  112.7  49.9   54.34
# 34999  Scoring PG  2020          payton pritchard  120.6  56.3   60.08
# 38013  Scoring PG  2019                 saben lee  102.5  50.6   55.75
# 38014  Scoring PG  2020                 saben lee  108.4  53.0   58.02
# ...

# %%
predictions = s_pg_model.predict(x_train)
college_s_pg_train['test_score'] = predictions
college_s_pg_train.head(50)
# Out:
#               pos  year        player_name   Ortg   eFG  TS_per  AST_per  \
# 158    Scoring PG  2016      aaron holiday   94.5  46.2   50.03     21.1
# 159    Scoring PG  2017      aaron holiday  113.1  57.1   60.96     24.4
# 160    Scoring PG  2018      aaron holiday  112.9  55.7   60.87     29.9
# 1126   Scoring PG  2013        alex caruso   87.7  41.3   45.13     27.9
# 8444   Scoring PG  2018      collin sexton  109.6  49.8   56.66     27.8
# 9500   Scoring PG  2015   d'angelo russell  113.6  54.1   57.29     30.1
# 10782  Scoring PG  2017       de'aaron fox  110.7  49.7   54.81     28.6
# 11047  Scoring PG  2015       delon wright  125.2  54.5   61.66     32.8
# 11048  Scoring PG  2014       delon wright  119.2  57.2   63.34     29.3
# 11279  Scoring PG  2017    dennis smith jr  109.5  52.0   56.31     34.2
# 11619  Scoring PG  2017      derrick white  121.1  58.1   62.67     28.3
# 12197  Scoring PG  2016    devonte' graham  117.4  57.4   59.89     19.5
# ...

# %%
college_s_pg_train['diff'] = college_s_pg_train['test_score'] - college_s_pg_train['score']
college_s_pg_train.to_csv('analyse_s_pg_scores.csv')

# %%
#Stretch 4 training
college_s_4_train = college_s_4_train.dropna()
x_train = college_s_4_train.iloc[:,3:-2].values
y_train = college_s_4_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_s_4_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
s_4_model = LinearRegression()

# to create the model, we use fit(x,y)
s_4_model.fit(x_train,y_train)

predictions = s_4_model.predict(x_pred)

# %%
college_s_4_pred['test_score'] = predictions
college_s_4_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/3396937754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_s_4_pred['test_score'] = predictions
#              pos  year      player_name   Ortg   eFG  TS_per  twoPM    porpag  \
# 194    Stretch 4  2019    aaron nesmith  104.4  49.3   53.65     55  2.133440
# 7907   Stretch 4  2019      chuma okeke  119.1  57.7   59.80    113  4.058000
# 17326  Stretch 4  2019      isaiah roby  102.9  49.7   53.19    120  2.757000
# 18048  Stretch 4  2020  jaden mcdaniels   91.9  46.9   51.52     93  1.890950
# 22673  Stretch 4  2020      jordan bell   96.5  45.7   48.10     76  1.074530
# 22674  Stretch 4  2019      jordan bell   88.5  42.3   46.28     20  0.050257
# ...

# %%
predictions = s_4_model.predict(x_train)
college_s_4_train['test_score'] = predictions
college_s_4_train.head(50)
# Out:
#              pos  year          player_name   Ortg   eFG  TS_per  twoPM  \
# 298    Stretch 4  2013          abdel nader   80.2  38.6   42.60     63
# 299    Stretch 4  2012          abdel nader   78.5  38.1   41.91     74
# 2241   Stretch 4  2013      anthony bennett  112.8  57.5   60.36    156
# 4529   Stretch 4  2016       brandon ingram  112.1  52.5   55.25    134
# 6639   Stretch 4  2011     chandler parsons  110.3  54.6   55.14    112
# 7325   Stretch 4  2010        chris johnson  116.4  52.4   57.06     73
# 7327   Stretch 4  2012        chris johnson  122.2  58.7   62.37     62
# 12902  Stretch 4  2018     donovan mitchell  103.7  60.2   61.99     16
# 13044  Stretch 4  2015  dorian finney smith  107.9  55.7   56.35     88
# 13045  Stretch 4  2016  dorian finney smith  113.7  52.8   56.94     98
# 13047  Stretch 4  2012  dorian finney smith   92.9  39.4   42.73     43
# 13089  Stretch 4  2013       doug mcdermott  121.3  62.3   67.19    207
# ...

# %%
college_s_4_train['diff'] = college_s_4_train['test_score'] - college_s_4_train['score']
college_s_4_train.to_csv('analyse_s_4_scores.csv')

# %%
#Wing g training
college_w_g_train = college_w_g_train.dropna()
x_train = college_w_g_train.iloc[:,3:-2].values
y_train = college_w_g_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_w_g_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
w_g_model = LinearRegression()

# to create the model, we use fit(x,y)
w_g_model.fit(x_train,y_train)

predictions = w_g_model.predict(x_pred)

# %%
college_w_g_pred['test_score'] = predictions
college_w_g_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/902990403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_w_g_pred['test_score'] = predictions
#           pos  year          player_name   Ortg   eFG  TS_per  twoPM  \
# 195    Wing G  2020        aaron nesmith  125.1  65.9   68.53     45
# 2317   Wing G  2020      anthony edwards  103.0  47.0   51.73    126
# 2915   Wing G  2019        armoni brooks  116.0  54.7   55.28     51
# 4693   Wing G  2021         brandon rush  115.9  59.2   60.70     64
# 5758   Wing G  2019         caleb martin  111.5  51.7   55.80     94
# 11749  Wing G  2019         desmond bane  121.8  58.2   60.72    147
# 11750  Wing G  2020         desmond bane  112.2  54.9   56.54    100
# ...

# %%
predictions = w_g_model.predict(x_train)
college_w_g_train['test_score'] = predictions
college_w_g_train.head(50)
# Out:
#           pos  year       player_name   Ortg   eFG  TS_per  twoPM    porpag  \
# 296    Wing G  2016       abdel nader  103.5  55.5   58.35    109  2.485400
# 1023   Wing G  2010        alec burks  117.0  56.7   62.49    144  5.031400
# 1024   Wing G  2011        alec burks  116.2  49.8   57.71    215  5.613440
# 1457   Wing G  2013      allen crabbe  108.7  52.8   56.83    151  4.681270
# 1459   Wing G  2011      allen crabbe  112.6  54.5   58.20     77  3.269360
# 2813   Wing G  2013    archie goodwin   96.9  46.4   50.91    140  2.613080
# 3691   Wing G  2013      ben mclemore  118.7  58.6   63.26    125  4.475410
# 4258   Wing G  2012      bradley beal  112.3  52.5   57.45    112  4.313430
# 5301   Wing G  2017       bruce brown  111.5  51.5   55.94    101  3.363130
# 5537   Wing G  2013       bryn forbes  108.2  52.0   56.46     69  2.608850
# 5610   Wing G  2013       buddy hield   97.2  43.3   46.66     62  1.433440
# ...

# %%
college_w_g_train['diff'] = college_w_g_train['test_score'] - college_w_g_train['score']
college_w_g_train.to_csv('analyse_w_g_scores.csv')

# %%
#Wing f training
college_w_f_train = college_w_f_train.dropna()
x_train = college_w_f_train.iloc[:,3:-2].values
y_train = college_w_f_train.iloc[:,-1].values
y_train = y_train.reshape(-1, 1)
x_pred = college_w_f_pred.iloc[:,3:-2].values

# %%
# create an empty linear regression model like below and give it a good variable name
w_f_model = LinearRegression()

# to create the model, we use fit(x,y)
w_f_model.fit(x_train,y_train)

predictions = w_f_model.predict(x_pred)

# %%
college_w_f_pred['test_score'] = predictions
college_w_f_pred
# Out:
# C:\Users\xavim\AppData\Local\Temp/ipykernel_18404/3583333437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   college_w_f_pred['test_score'] = predictions
#           pos  year       player_name   usg  DRB_per  twoPM  blk_per  \
# 5890   Wing F  2019       cam reddish  23.6     10.6     65      1.9
# 10834  Wing F  2019   de'andre hunter  23.5     13.4    159      2.4
# 14513  Wing F  2019     eric paschall  23.8     16.0    125      1.6
# 16190  Wing F  2019    grant williams  27.0     17.4    215      5.3
# 20023  Wing F  2021    jason thompson  12.6     10.2     18      1.5
# 25719  Wing F  2019    keldon johnson  21.7     16.5    127      0.6
# 33012  Wing F  2019     naji marshall  25.6     19.9    118      0.7
# ...

# %%
predictions = w_f_model.predict(x_train)
college_w_f_train['test_score'] = predictions
college_w_f_train.head(50)
# Out:
#           pos  year       player_name   usg  DRB_per  twoPM  blk_per  \
# 137    Wing F  2014      aaron gordon  23.2     19.3    173      3.4
# 297    Wing F  2015       abdel nader  21.1     14.5     54      3.0
# 1458   Wing F  2012      allen crabbe  21.4     16.5     96      1.8
# 2115   Wing F  2014    andrew wiggins  25.1     12.3    146      3.1
# 3731   Wing F  2016       ben simmons  28.2     26.8    215      2.5
# 6640   Wing F  2010  chandler parsons  20.8     16.9    103      0.5
# 7326   Wing F  2011     chris johnson  18.8     14.8     57      1.6
# 8279   Wing F  2015       cody martin  22.2     10.5     28      2.9
# 9380   Wing F  2017    damyean dotson  21.2     18.2     94      0.6
# 9381   Wing F  2016    damyean dotson  18.9     17.2    102      0.7
# 9994   Wing F  2011     darius miller  17.2     11.2     91      3.6
# 9996   Wing F  2012     darius miller  18.6      7.3     87      1.2
# 10833  Wing F  2018   de'andre hunter  25.4     14.9     83      2.7
# ...

# %%
college_w_f_train['diff'] = college_w_f_train['test_score'] - college_w_f_train['score']
college_w_f_train.to_csv('analyse_w_f_scores.csv')

# %% [markdown]
# # Applying algorithms to all players now

# %%
college_c = pd.read_csv("c_test_college_df.csv", index_col=0)
college_c_g = pd.read_csv("c_g_test_college_df.csv", index_col=0)
college_pf_c = pd.read_csv("pf_c_test_college_df.csv", index_col=0)
college_p_pg = pd.read_csv("p_pg_test_college_df.csv", index_col=0)
college_s_pg = pd.read_csv("s_pg_test_college_df.csv", index_col=0)
college_s_4 = pd.read_csv("s_4_test_college_df.csv", index_col=0)
college_w_g = pd.read_csv("w_g_test_college_df.csv", index_col=0)
college_w_f = pd.read_csv("w_f_test_college_df.csv", index_col=0)
college_df_final = pd.read_csv("college_df_final_scores.csv", index_col=0)

# %%
# Out:
#               pos  year     player_name   Ortg   eFG  TS_per  twoPM    porpag  \
# id
# 0         Pure PG  2016   aakim saintil   99.7  42.4   51.19     78  1.326970
# 0      Scoring PG  2014   aakim saintil   90.7  38.8   45.78     32  0.154813
# 2      Scoring PG  2020  aamahne santos   91.3  43.4   45.46     41 -0.056414
# 2         Combo G  2019  aamahne santos   94.8  44.5   48.35     27 -0.305204
# 4         Pure PG  2010  aamir mccleary   83.4  39.2   43.97     56  0.353716
# ...           ...   ...             ...    ...   ...     ...    ...       ...
# 22432        PF/C  2019  zylan cheatham  103.4  55.4   57.81    132  2.271030
# 22432           C  2016  zylan cheatham  102.3  53.1   59.30     83  1.346490
# 22432        PF/C  2017  zylan cheatham  108.6  52.6   58.89     88  2.036550
# 22435  Scoring PG  2021     zyon pullin  113.0  53.1   56.48     81  3.185820
# 22435     Combo G  2022     zyon pullin  107.6  50.4   56.84    111  3.573150
#
# ...

# %%
# P PG 
x_pred = college_p_pg.iloc[:,3:-1].values
predictions = p_pg_model.predict(x_pred)
college_df_final['p_pg_score'] = predictions

# %%
# C G 
x_pred = college_c_g.iloc[:,3:-1].values
predictions = c_g_model.predict(x_pred)
college_df_final['c_g_score'] = predictions

# %%
# S PG 
x_pred = college_s_pg.iloc[:,3:-1].values
predictions = s_pg_model.predict(x_pred)
college_df_final['s_pg_score'] = predictions

# %%
# C
x_pred = college_c.iloc[:,3:-1].values
predictions = c_model.predict(x_pred)
college_df_final['c_score'] = predictions

# %%
# pf/C
x_pred = college_pf_c.iloc[:,3:-1].values
predictions = pf_c_model.predict(x_pred)
college_df_final['pf_c_score'] = predictions

# %%
# s 4
x_pred = college_s_4.iloc[:,3:-1].values
predictions = s_4_model.predict(x_pred)
college_df_final['s_4_score'] = predictions

# %%
# w G 
x_pred = college_w_g.iloc[:,3:-1].values
predictions = w_g_model.predict(x_pred)
college_df_final['w_g_score'] = predictions

# %%
# w f
x_pred = college_w_f.iloc[:,3:-1].values
predictions = w_f_model.predict(x_pred)
college_df_final['w_f_score'] = predictions

# %%
'''
#Who are the best players in the nba


best_player = pd.DataFrame({'Score': college_c_g['test_score'],
                           'Name': college_c_g['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\n#Who are the best players in the nba\n\n\nbest_player = pd.DataFrame({'Score': college_c_g['test_score'],\n                           'Name': college_c_g['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
#college_c_g.to_csv('analyse_c_g_final_scores.csv')

# %%
'''
best_player = pd.DataFrame({'Score': college_p_pg['test_score'],
                           'Name': college_p_pg['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_p_pg['test_score'],\n                           'Name': college_p_pg['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
#college_p_pg.to_csv('college_p_pg_final_scores.csv')

# %%
'''
best_player = pd.DataFrame({'Score': college_s_pg['test_score'],
                           'Name': college_s_pg['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_s_pg['test_score'],\n                           'Name': college_s_pg['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
#college_s_pg.to_csv('college_s_pg_final_scores.csv')

# %%
'''
best_player = pd.DataFrame({'Score': college_s_4['test_score'],
                           'Name': college_s_4['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_s_4['test_score'],\n                           'Name': college_s_4['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
#college_s_4.to_csv('college_s_4_final_scores.csv')

# %%
'''
best_player = pd.DataFrame({'Score': college_pf_c['test_score'],
                           'Name': college_pf_c['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_pf_c['test_score'],\n                           'Name': college_pf_c['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
'''
best_player = pd.DataFrame({'Score': college_c['test_score'],
                           'Name': college_c['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_c['test_score'],\n                           'Name': college_c['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
'''
best_player = pd.DataFrame({'Score': college_w_g['test_score'],
                           'Name': college_w_g['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_w_g['test_score'],\n                           'Name': college_w_g['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
#college_w_g.to_csv('college_w_g_final_scores.csv')

# %%
'''
best_player = pd.DataFrame({'Score': college_w_f['test_score'],
                           'Name': college_w_f['player_name']})

best_player = best_player.sort_values(by='Score', ascending = False).head(20)


best_player
'''
# Out:
# "\nbest_player = pd.DataFrame({'Score': college_w_f['test_score'],\n                           'Name': college_w_f['player_name']})\n\nbest_player = best_player.sort_values(by='Score', ascending = False).head(20)\n\n\nbest_player\n"

# %%
college_df_final.head()
# Out:
#            pos  year     player_name  Ortg   usg   eFG  TS_per  ORB_per  \
# id
# 0      Pure PG  2016   aakim saintil  99.7  25.1  42.4   51.19      1.4
# 0   Scoring PG  2014   aakim saintil  90.7  18.8  38.8   45.78      2.4
# 2   Scoring PG  2020  aamahne santos  91.3  16.9  43.4   45.46      1.0
# 2      Combo G  2019  aamahne santos  94.8  13.6  44.5   48.35      1.3
# 4      Pure PG  2010  aamir mccleary  83.4  27.1  39.2   43.97      1.9
#
#     DRB_per  AST_per  ...      dbpm     gbpm  p_pg_score  c_g_score  \
# id                    ...
# 0       6.9     30.7  ... -3.296980 -2.77093   45.527666  47.526453
# 0       7.2     16.8  ... -0.933676 -3.76000   42.326090  31.495142
# 2       7.5     17.7  ... -1.257820 -3.09113   34.457957  34.567496
# 2       5.7     13.6  ... -2.608980 -4.17229   29.941007  26.954309
# 4      12.7     36.7  ... -1.894260 -4.48713   45.608076  50.768873
#
#     s_pg_score    c_score  pf_c_score  s_4_score  w_g_score  w_f_score
# id
# ...

# %%
college_df_final['guard_score'] = (college_df_final['p_pg_score'] + college_df_final['c_g_score'] + college_df_final['s_pg_score'] + college_df_final['w_g_score'])/4

# %%
college_df_final['forward_score'] = (college_df_final['s_4_score'] + college_df_final['w_f_score'] + college_df_final['pf_c_score'])/3

# %%
college_df_final['centre_score'] = (college_df_final['c_score'] + college_df_final['pf_c_score'])/2

# %%
college_df_final.to_csv('college_df_with_scores.csv')
