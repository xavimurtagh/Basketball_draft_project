# %%
# importing libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
# for visualisation
import matplotlib.pyplot as plt

# %%
#Importing the datasets
college_df = pd.read_csv("college_ratings_test.csv")
college_df.head()
# Out:
#      player_name           team conf  GP  Min_per   Ortg   usg   eFG  TS_per  \
# 0  Aakim Saintil   LIU Brooklyn  NEC  31     72.2   99.7  25.1  42.4   51.19
# 1  Aakim Saintil  South Alabama   SB  28     56.5   90.7  18.8  38.8   45.78
# 2     Aalim Moor   San Jose St.  WAC  20     17.6   92.1  14.6  53.6   53.57
# 3     Aalim Moor   San Jose St.  WAC  12      3.8  120.2  11.1  68.2   68.18
# 4     Aalim Moor   San Jose St.  WAC  16      3.8  121.4   8.6  57.1   57.14
#
#    ORB_per  ...     dgbpm    oreb    dreb    treb     ast     stl     blk  \
# 0      1.4  ... -1.843510  0.3871  1.8387  2.2258  4.7097  1.4839  0.0323
# 1      2.4  ...  0.537531  0.5000  1.4643  1.9643  1.8214  1.0000  0.0714
# 2      1.0  ...  0.625015  0.1000  0.5500  0.6500  0.9500  0.3500  0.1500
# 3      0.0  ...  0.643061  0.0000  0.2500  0.2500  0.0000  0.1667  0.0000
# 4      2.2  ... -1.043050  0.0625  0.2500  0.3125  0.2500  0.0000  0.0000
#
#        pts         pos      unk
# 0  12.6452     Pure PG  7.80165
# 1   6.2500  Scoring PG  6.25566
# 2   2.2500     Pure PG  5.65181
# 3   1.2500     Combo G  6.56432
# 4   0.5000      Wing G  0.00000
#
# [5 rows x 66 columns]

# %%
college_df = college_df[college_df['GP'] > 10]

# %%
college_df = college_df[college_df['Min_per'] > 9]

# %%
college_df.to_csv('college_ratings_test.csv')
